// %%
#include <iostream>

/*a workaround to solve cling issue*/
#include "../inc/macos_cling_workaround.hpp"
/*set libtorch path, load libs*/
#include "../inc/load_libtorch.hpp"
/*import custom defined macros*/
#include "../inc/custom_def.hpp"
/*import matplotlibcpp*/
#include "../inc/load_matplotlibcpp.hpp"

/*import libtorch header file*/
#include <torch/torch.h>

// %% [markdown]
// # 图像分类数据集：Fasion-MNIST
//
// ***注意：libtorch官方有MNIST数据集分类[例程](https://pytorch.org/cppdocs/frontend.html)，需要的可以自行参考；***
//
// fashion-mnist数据集与mnist数据集的文件类型、数据格式一样，因此可以考虑搬用MNIST的处理代码；

// %%
struct Net : torch::nn::Module {
  Net() {
    // Construct and register two Linear submodules.
    fc1 = register_module("fc1", torch::nn::Linear(784, 64));
    fc2 = register_module("fc2", torch::nn::Linear(64, 32));
    fc3 = register_module("fc3", torch::nn::Linear(32, 10));
  }

  // Implement the Net's algorithm.
  torch::Tensor forward(torch::Tensor x) {
    // Use one of many tensor manipulation functions.
    x = torch::relu(fc1->forward(x.reshape({x.size(0), 784})));
    x = torch::dropout(x, /*p=*/0.5, /*train=*/is_training());
    x = torch::relu(fc2->forward(x));
    x = torch::log_softmax(fc3->forward(x), /*dim=*/1);
    return x;
  }

  // Use one of many "standard library" modules.
  torch::nn::Linear fc1{nullptr}, fc2{nullptr}, fc3{nullptr};
};

// %%
// Create a new Net.
auto net = std::make_shared<Net>();

// Create a multi-threaded data loader for the MNIST dataset.
auto data_loader = torch::data::make_data_loader(
  torch::data::datasets::MNIST("../dataset/fashion_mnist").map(
      torch::data::transforms::Stack<>()),
  /*batch_size=*/64);

// Instantiate an SGD optimization algorithm to update our Net's parameters.
torch::optim::SGD optimizer(net->parameters(), /*lr=*/0.01);

for (size_t epoch = 1; epoch <= 10; ++epoch) {
    size_t batch_index = 0;
    // Iterate the data loader to yield batches from the dataset.
    for (auto& batch : *data_loader) {
        // Reset gradients.
        optimizer.zero_grad();
        // Execute the model on the input data.
        torch::Tensor prediction = net->forward(batch.data);
        // Compute a loss value to judge the prediction of our model.
        torch::Tensor loss = torch::nll_loss(prediction, batch.target);
        // Compute gradients of the loss w.r.t. the parameters of our model.
        loss.backward();
        // Update the parameters based on the calculated gradients.
        optimizer.step();
        // Output the loss and checkpoint every 100 batches.
        if (++batch_index % 100 == 0) {
        std::cout << "Epoch: " << epoch << " | Batch: " << batch_index
                  << " | Loss: " << loss.item<float>() << std::endl;
        // Serialize your model periodically as a checkpoint.
        torch::save(net, "net.pt");
        }
    }
}
// Out:
// Epoch: 1 | Batch: 100 | Loss: 2.27081
// Epoch: 1 | Batch: 200 | Loss: 2.19506
// Epoch: 1 | Batch: 300 | Loss: 2.05596
// Epoch: 1 | Batch: 400 | Loss: 1.81763
// Epoch: 1 | Batch: 500 | Loss: 1.67282
// Epoch: 1 | Batch: 600 | Loss: 1.40453
// Epoch: 1 | Batch: 700 | Loss: 1.39304
// Epoch: 1 | Batch: 800 | Loss: 1.2589
// Epoch: 1 | Batch: 900 | Loss: 1.23028
// Epoch: 2 | Batch: 100 | Loss: 1.17093
// Epoch: 2 | Batch: 200 | Loss: 1.13692
// Epoch: 2 | Batch: 300 | Loss: 1.13083
// Epoch: 2 | Batch: 400 | Loss: 0.913697
// Epoch: 2 | Batch: 500 | Loss: 0.970913
// Epoch: 2 | Batch: 600 | Loss: 0.916977
// Epoch: 2 | Batch: 700 | Loss: 0.905381
// Epoch: 2 | Batch: 800 | Loss: 0.875823
// Epoch: 2 | Batch: 900 | Loss: 0.817854
// Epoch: 3 | Batch: 100 | Loss: 1.0972
// Epoch: 3 | Batch: 200 | Loss: 0.833972
// Epoch: 3 | Batch: 300 | Loss: 0.795917
// Epoch: 3 | Batch: 400 | Loss: 0.754265
// Epoch: 3 | Batch: 500 | Loss: 1.02549
// Epoch: 3 | Batch: 600 | Loss: 0.762818
// Epoch: 3 | Batch: 700 | Loss: 0.652777
// Epoch: 3 | Batch: 800 | Loss: 0.765372
// Epoch: 3 | Batch: 900 | Loss: 0.821454
// Epoch: 4 | Batch: 100 | Loss: 0.718817
// Epoch: 4 | Batch: 200 | Loss: 0.599971
// Epoch: 4 | Batch: 300 | Loss: 0.633135
// Epoch: 4 | Batch: 400 | Loss: 0.794047
// Epoch: 4 | Batch: 500 | Loss: 0.794451
// Epoch: 4 | Batch: 600 | Loss: 0.922433
// Epoch: 4 | Batch: 700 | Loss: 0.702364
// Epoch: 4 | Batch: 800 | Loss: 0.824238
// Epoch: 4 | Batch: 900 | Loss: 0.836094
// Epoch: 5 | Batch: 100 | Loss: 0.58219
// Epoch: 5 | Batch: 200 | Loss: 0.734703
// Epoch: 5 | Batch: 300 | Loss: 0.57418
// Epoch: 5 | Batch: 400 | Loss: 0.792068
// Epoch: 5 | Batch: 500 | Loss: 0.610923
// Epoch: 5 | Batch: 600 | Loss: 0.71083
// Epoch: 5 | Batch: 700 | Loss: 0.617755
// Epoch: 5 | Batch: 800 | Loss: 0.797102
// Epoch: 5 | Batch: 900 | Loss: 0.852458
// Epoch: 6 | Batch: 100 | Loss: 0.696501
// Epoch: 6 | Batch: 200 | Loss: 0.744853
// Epoch: 6 | Batch: 300 | Loss: 0.72155
// Epoch: 6 | Batch: 400 | Loss: 0.614258
// Epoch: 6 | Batch: 500 | Loss: 0.598285
// Epoch: 6 | Batch: 600 | Loss: 0.662409
// Epoch: 6 | Batch: 700 | Loss: 0.669303
// Epoch: 6 | Batch: 800 | Loss: 0.680719
// Epoch: 6 | Batch: 900 | Loss: 0.470522
// Epoch: 7 | Batch: 100 | Loss: 0.520137
// Epoch: 7 | Batch: 200 | Loss: 0.798507
// Epoch: 7 | Batch: 300 | Loss: 0.619001
// Epoch: 7 | Batch: 400 | Loss: 0.677151
// Epoch: 7 | Batch: 500 | Loss: 0.665543
// Epoch: 7 | Batch: 600 | Loss: 0.540033
// Epoch: 7 | Batch: 700 | Loss: 0.522694
// Epoch: 7 | Batch: 800 | Loss: 0.547869
// Epoch: 7 | Batch: 900 | Loss: 0.730732
// Epoch: 8 | Batch: 100 | Loss: 0.801698
// Epoch: 8 | Batch: 200 | Loss: 0.687167
// Epoch: 8 | Batch: 300 | Loss: 0.396871
// Epoch: 8 | Batch: 400 | Loss: 0.38888
// Epoch: 8 | Batch: 500 | Loss: 0.494437
// Epoch: 8 | Batch: 600 | Loss: 0.584502
// Epoch: 8 | Batch: 700 | Loss: 0.534607
// Epoch: 8 | Batch: 800 | Loss: 0.56581
// Epoch: 8 | Batch: 900 | Loss: 0.430732
// Epoch: 9 | Batch: 100 | Loss: 0.593522
// Epoch: 9 | Batch: 200 | Loss: 0.56129
// Epoch: 9 | Batch: 300 | Loss: 0.67445
// Epoch: 9 | Batch: 400 | Loss: 0.536902
// Epoch: 9 | Batch: 500 | Loss: 0.869258
// Epoch: 9 | Batch: 600 | Loss: 0.550981
// Epoch: 9 | Batch: 700 | Loss: 0.610722
// Epoch: 9 | Batch: 800 | Loss: 0.434433
// Epoch: 9 | Batch: 900 | Loss: 0.490636
// Epoch: 10 | Batch: 100 | Loss: 0.496532
// Epoch: 10 | Batch: 200 | Loss: 0.521376
// Epoch: 10 | Batch: 300 | Loss: 0.639258
// Epoch: 10 | Batch: 400 | Loss: 0.489592
// Epoch: 10 | Batch: 500 | Loss: 0.475637
// Epoch: 10 | Batch: 600 | Loss: 0.48247
// Epoch: 10 | Batch: 700 | Loss: 0.672437
// Epoch: 10 | Batch: 800 | Loss: 0.495531
// Epoch: 10 | Batch: 900 | Loss: 0.790602
